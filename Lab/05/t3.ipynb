# %%
import random
p_cnt = 10
c_cnt = 10
max_gen = 100
mut_rate = 0.2
# Generate Poplation

def generate():
    cities = list(range(c_cnt))
    population = [random.sample(cities, len(cities)) for _ in range(p_cnt)]
    return population

print(generate())
# Out:
# [[3, 0, 5, 6, 1, 8, 9, 2, 7, 4], [4, 5, 3, 8, 9, 2, 6, 7, 0, 1], [0, 5, 2, 7, 4, 8, 6, 1, 3, 9], [5, 8, 1, 3, 4, 2, 0, 9, 6, 7], [1, 6, 3, 4, 9, 0, 8, 2, 5, 7], [1, 2, 9, 5, 0, 4, 8, 3, 7, 6], [6, 3, 0, 1, 9, 7, 2, 4, 8, 5], [7, 9, 6, 0, 1, 5, 2, 4, 8, 3], [1, 2, 7, 5, 6, 9, 3, 4, 0, 8], [3, 8, 4, 1, 6, 2, 9, 7, 0, 5]]

# %%
# fitness Function

dist_matrix = [
    [ 0, 29, 20, 21, 16, 31, 100, 12,  4, 31], 
    [29,  0, 15, 29, 28, 40, 72, 21, 29, 41], 
    [20, 15,  0, 15, 14, 25, 81,  9, 23, 27], 
    [21, 29, 15,  0,  4, 12, 92, 12, 25, 13], 
    [16, 28, 14,  4,  0, 16, 94,  9, 20, 16], 
    [31, 40, 25, 12, 16,  0, 95, 24, 36,  3], 
    [100,72, 81, 92, 94, 95,  0, 90, 101,99], 
    [12, 21,  9, 12,  9, 24, 90,  0, 15, 25], 
    [4,  29, 23, 25, 20, 36, 101, 15,  0, 35], 
    [31, 41, 27, 13, 16, 3,  99, 25, 35,  0]
]

def Fitness_Function(route):
    total_distance = 0
    for i in range(len(route) - 1):
        total_distance += dist_matrix[route[i]][route[i + 1]]
    total_distance += dist_matrix[route[-1]][route[0]]  
    return 1/total_distance

# %%
#Select Parents

def select(population,fitnessvalues):
    sortedpop = [route for route,_ in sorted(zip(population,fitnessvalues))]
    return sortedpop[:len(sortedpop)//2]

# %%
# Order Crossover (OX)
def crossover(p1, p2):
    size = len(p1)
    start, end = sorted(random.sample(range(size), 2))
    child = [None] * size
    child[start:end] = p1[start:end]
    remaining = [gene for gene in p2 if gene not in child]
    idx = 0
    for i in range(size):
        if child[i] is None:
            child[i] = remaining[idx]
            idx += 1
    return child

# %%
# Mutate

def mutate(route):
    i,j = random.sample(range(c_cnt),2)
    route[i],route[j] = route[j],route[i]
    return route

# %%
# Main Genetic Algorithm
population = generate()
gen = 0

while gen < max_gen:
    fitness_scores = [Fitness_Function(ind) for ind in population]
    best_distance = 1 / max(fitness_scores)  # Convert back to distance
    print(f"Generation {gen} Best Distance: {best_distance}")
    
    parents = select(population, fitness_scores)
    newpop = []

    for _ in range(p_cnt):
        p1, p2 = random.sample(parents, 2)
        child = crossover(p1, p2)
        if random.random() < mut_rate:
            child = mutate(child)
        newpop.append(child)
    
    population = newpop
    gen += 1

# Get Best Route After Last Generation
fitness_scores = [Fitness_Function(ind) for ind in population]
best_route = min(population, key=Fitness_Function)
best_distance = 1 / Fitness_Function(best_route)
print("Best Route:", best_route)
print("Best Distance:", best_distance)
# Out:
# Generation 0 Best Distance: 287.0
# Generation 1 Best Distance: 301.0
# Generation 2 Best Distance: 312.0
# Generation 3 Best Distance: 318.0
# Generation 4 Best Distance: 328.0
# Generation 5 Best Distance: 326.0
# Generation 6 Best Distance: 281.0
# Generation 7 Best Distance: 332.0
# Generation 8 Best Distance: 351.0
# Generation 9 Best Distance: 294.0
# Generation 10 Best Distance: 351.0
# Generation 11 Best Distance: 338.0
# Generation 12 Best Distance: 298.0
# Generation 13 Best Distance: 315.0
# Generation 14 Best Distance: 348.0
# Generation 15 Best Distance: 364.0
# Generation 16 Best Distance: 373.0
# Generation 17 Best Distance: 353.0
# Generation 18 Best Distance: 367.0
# Generation 19 Best Distance: 343.0
# Generation 20 Best Distance: 373.0
# Generation 21 Best Distance: 368.0
# Generation 22 Best Distance: 352.0
# Generation 23 Best Distance: 368.0
# Generation 24 Best Distance: 339.0
# Generation 25 Best Distance: 370.0
# Generation 26 Best Distance: 367.0
# Generation 27 Best Distance: 351.0
# Generation 28 Best Distance: 351.0
# Generation 29 Best Distance: 328.0
# Generation 30 Best Distance: 339.0
# Generation 31 Best Distance: 344.0
# Generation 32 Best Distance: 298.0
# Generation 33 Best Distance: 298.0
# Generation 34 Best Distance: 341.0
# Generation 35 Best Distance: 334.0
# Generation 36 Best Distance: 335.0
# Generation 37 Best Distance: 343.0
# Generation 38 Best Distance: 351.0
# Generation 39 Best Distance: 325.0
# Generation 40 Best Distance: 335.0
# Generation 41 Best Distance: 343.0
# Generation 42 Best Distance: 351.0
# Generation 43 Best Distance: 353.0
# Generation 44 Best Distance: 353.0
# Generation 45 Best Distance: 353.0
# Generation 46 Best Distance: 351.0
# Generation 47 Best Distance: 314.0
# Generation 48 Best Distance: 313.0
# Generation 49 Best Distance: 353.0
# Generation 50 Best Distance: 313.0
# Generation 51 Best Distance: 352.0
# Generation 52 Best Distance: 352.0
# Generation 53 Best Distance: 333.0
# Generation 54 Best Distance: 335.0
# Generation 55 Best Distance: 347.0
# Generation 56 Best Distance: 352.0
# Generation 57 Best Distance: 347.0
# Generation 58 Best Distance: 352.0
# Generation 59 Best Distance: 325.0
# Generation 60 Best Distance: 337.0
# Generation 61 Best Distance: 325.0
# Generation 62 Best Distance: 325.0
# Generation 63 Best Distance: 314.0
# Generation 64 Best Distance: 340.0
# Generation 65 Best Distance: 335.0
# Generation 66 Best Distance: 335.0
# Generation 67 Best Distance: 335.0
# Generation 68 Best Distance: 350.0
# Generation 69 Best Distance: 342.0
# Generation 70 Best Distance: 352.0
# Generation 71 Best Distance: 349.0
# Generation 72 Best Distance: 352.0
# Generation 73 Best Distance: 325.0
# Generation 74 Best Distance: 314.0
# Generation 75 Best Distance: 333.0
# Generation 76 Best Distance: 352.0
# Generation 77 Best Distance: 346.0
# Generation 78 Best Distance: 342.0
# Generation 79 Best Distance: 342.0
# Generation 80 Best Distance: 335.0
# Generation 81 Best Distance: 350.0
# Generation 82 Best Distance: 344.0
# Generation 83 Best Distance: 333.0
# Generation 84 Best Distance: 347.0
# Generation 85 Best Distance: 307.0
# Generation 86 Best Distance: 325.0
# Generation 87 Best Distance: 307.0
# Generation 88 Best Distance: 352.0
# Generation 89 Best Distance: 344.0
# Generation 90 Best Distance: 352.0
# Generation 91 Best Distance: 352.0
# Generation 92 Best Distance: 352.0
# Generation 93 Best Distance: 325.0
# Generation 94 Best Distance: 352.0
# Generation 95 Best Distance: 335.0
# Generation 96 Best Distance: 347.0
# Generation 97 Best Distance: 325.0
# Generation 98 Best Distance: 340.0
# Generation 99 Best Distance: 346.0
# Best Route: [3, 1, 2, 0, 5, 4, 6, 7, 8, 9]
# Best Distance: 358.0
